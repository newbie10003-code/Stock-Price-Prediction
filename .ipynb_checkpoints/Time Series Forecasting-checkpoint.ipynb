# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras
import math

# %% [markdown]
# # Reading the Dataset

# %%
data = pd.read_csv('jena_climate_2009_2016.csv')

# %%
data.head()
# Out:
#              Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0  01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90    93.3
# 1  01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28    93.4
# 2  01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31    93.9
# 3  01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07    94.2
# 4  01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04    94.1
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 0          3.33          3.11          0.22       1.94             3.12
# 1          3.23          3.02          0.21       1.89             3.03
# 2          3.21          3.01          0.20       1.88             3.02
# 3          3.26          3.07          0.19       1.92             3.08
# 4          3.27          3.08          0.19       1.92             3.09
#
#    rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0       1307.75      1.03           1.75     152.3
# 1       1309.80      0.72           1.50     136.1
# 2       1310.24      0.19           0.63     171.6
# 3       1309.19      0.34           0.50     198.0
# 4       1309.00      0.32           0.63     214.3

# %%
data.describe()
# Out:
#             p (mbar)       T (degC)       Tpot (K)    Tdew (degC)  \
# count  420551.000000  420551.000000  420551.000000  420551.000000
# mean      989.212776       9.450147     283.492743       4.955854
# std         8.358481       8.423365       8.504471       6.730674
# min       913.600000     -23.010000     250.600000     -25.010000
# 25%       984.200000       3.360000     277.430000       0.240000
# 50%       989.580000       9.420000     283.470000       5.220000
# 75%       994.720000      15.470000     289.530000      10.070000
# max      1015.350000      37.280000     311.340000      23.110000
#
#               rh (%)   VPmax (mbar)   VPact (mbar)   VPdef (mbar)  \
# count  420551.000000  420551.000000  420551.000000  420551.000000
# mean       76.008259      13.576251       9.533756       4.042412
# std        16.476175       7.739020       4.184164       4.896851
# min        12.950000       0.950000       0.790000       0.000000
# 25%        65.210000       7.780000       6.210000       0.870000
# 50%        79.300000      11.820000       8.860000       2.190000
# 75%        89.400000      17.600000      12.350000       5.300000
# max       100.000000      63.770000      28.320000      46.010000
#
#            sh (g/kg)  H2OC (mmol/mol)   rho (g/m**3)       wv (m/s)  \
# count  420551.000000    420551.000000  420551.000000  420551.000000
# mean        6.022408         9.640223    1216.062748       1.702224
# std         2.656139         4.235395      39.975208      65.446714
# min         0.500000         0.800000    1059.450000   -9999.000000
# 25%         3.920000         6.290000    1187.490000       0.990000
# 50%         5.590000         8.960000    1213.790000       1.760000
# 75%         7.800000        12.490000    1242.770000       2.860000
# max        18.130000        28.820000    1393.540000      28.490000
#
#        max. wv (m/s)       wd (deg)
# count  420551.000000  420551.000000
# mean        3.056555     174.743738
# std        69.016932      86.681693
# min     -9999.000000       0.000000
# 25%         1.760000     124.900000
# 50%         2.960000     198.100000
# 75%         4.740000     234.100000
# max        23.500000     360.000000

# %%
data
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 0        93.30          3.33          3.11          0.22       1.94
# 1        93.40          3.23          3.02          0.21       1.89
# 2        93.90          3.21          3.01          0.20       1.88
# 3        94.20          3.26          3.07          0.19       1.92
# 4        94.10          3.27          3.08          0.19       1.92
# ...        ...           ...           ...           ...        ...
# 420546   73.10          4.52          3.30          1.22       2.06
# 420547   69.71          4.77          3.32          1.44       2.07
# 420548   67.91          4.84          3.28          1.55       2.05
# 420549   71.80          4.46          3.20          1.26       1.99
# 420550   75.70          4.27          3.23          1.04       2.01
#
#         H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0                  3.12       1307.75      1.03           1.75     152.3
# 1                  3.03       1309.80      0.72           1.50     136.1
# 2                  3.02       1310.24      0.19           0.63     171.6
# 3                  3.08       1309.19      0.34           0.50     198.0
# 4                  3.09       1309.00      0.32           0.63     214.3
# ...                 ...           ...       ...            ...       ...
# 420546             3.30       1292.98      0.67           1.52     240.0
# 420547             3.32       1289.44      1.14           1.92     234.3
# 420548             3.28       1288.39      1.08           2.00     215.2
# 420549             3.20       1293.56      1.49           2.16     225.8
# 420550             3.23       1296.38      1.23           1.96     184.9
#
# [420551 rows x 15 columns]

# %%
data = data[5::6]

# %%
data
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 5       01.01.2009 01:00:00    996.50     -8.05    265.38        -8.78
# 11      01.01.2009 02:00:00    996.62     -8.88    264.54        -9.77
# 17      01.01.2009 03:00:00    996.84     -8.81    264.59        -9.66
# 23      01.01.2009 04:00:00    996.99     -9.05    264.34       -10.02
# 29      01.01.2009 05:00:00    997.46     -9.63    263.72       -10.65
# ...                     ...       ...       ...       ...          ...
# 420521  31.12.2016 19:10:00   1002.18     -0.98    272.01        -5.36
# 420527  31.12.2016 20:10:00   1001.40     -1.40    271.66        -6.84
# 420533  31.12.2016 21:10:00   1001.19     -2.75    270.32        -6.90
# 420539  31.12.2016 22:10:00   1000.65     -2.89    270.22        -7.15
# 420545  31.12.2016 23:10:00   1000.11     -3.93    269.23        -8.09
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 5        94.40          3.33          3.14          0.19       1.96
# 11       93.20          3.12          2.90          0.21       1.81
# 17       93.50          3.13          2.93          0.20       1.83
# 23       92.60          3.07          2.85          0.23       1.78
# 29       92.20          2.94          2.71          0.23       1.69
# ...        ...           ...           ...           ...        ...
# 420521   72.00          5.69          4.09          1.59       2.54
# 420527   66.29          5.51          3.65          1.86       2.27
# 420533   72.90          4.99          3.64          1.35       2.26
# 420539   72.30          4.93          3.57          1.37       2.22
# 420545   72.60          4.56          3.31          1.25       2.06
#
#         H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 5                  3.15       1307.86      0.21           0.63     192.7
# 11                 2.91       1312.25      0.25           0.63     190.3
# 17                 2.94       1312.18      0.18           0.63     167.2
# 23                 2.85       1313.61      0.10           0.38     240.0
# 29                 2.71       1317.19      0.40           0.88     157.0
# ...                 ...           ...       ...            ...       ...
# 420521             4.08       1280.70      0.87           1.36     190.6
# 420527             3.65       1281.87      1.02           1.92     225.4
# 420533             3.63       1288.02      0.71           1.56     158.7
# 420539             3.57       1288.03      0.35           0.68     216.7
# 420545             3.31       1292.41      0.56           1.00     202.6
#
# [70091 rows x 15 columns]

# %%
data.reset_index(inplace = True)

# %%
data.drop("index", axis = 1)
# Out:
#                  Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0      01.01.2009 01:00:00    996.50     -8.05    265.38        -8.78   94.40
# 1      01.01.2009 02:00:00    996.62     -8.88    264.54        -9.77   93.20
# 2      01.01.2009 03:00:00    996.84     -8.81    264.59        -9.66   93.50
# 3      01.01.2009 04:00:00    996.99     -9.05    264.34       -10.02   92.60
# 4      01.01.2009 05:00:00    997.46     -9.63    263.72       -10.65   92.20
# ...                    ...       ...       ...       ...          ...     ...
# 70086  31.12.2016 19:10:00   1002.18     -0.98    272.01        -5.36   72.00
# 70087  31.12.2016 20:10:00   1001.40     -1.40    271.66        -6.84   66.29
# 70088  31.12.2016 21:10:00   1001.19     -2.75    270.32        -6.90   72.90
# 70089  31.12.2016 22:10:00   1000.65     -2.89    270.22        -7.15   72.30
# 70090  31.12.2016 23:10:00   1000.11     -3.93    269.23        -8.09   72.60
#
#        VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 0              3.33          3.14          0.19       1.96             3.15
# 1              3.12          2.90          0.21       1.81             2.91
# 2              3.13          2.93          0.20       1.83             2.94
# 3              3.07          2.85          0.23       1.78             2.85
# 4              2.94          2.71          0.23       1.69             2.71
# ...             ...           ...           ...        ...              ...
# 70086          5.69          4.09          1.59       2.54             4.08
# 70087          5.51          3.65          1.86       2.27             3.65
# 70088          4.99          3.64          1.35       2.26             3.63
# 70089          4.93          3.57          1.37       2.22             3.57
# 70090          4.56          3.31          1.25       2.06             3.31
#
#        rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 
# [[[1], [2], [3], [4], [5]]] ==> [6]
# [[[2], [3], [4], [5], [6]]] ==> [7]
# [[[3], [4], [5], [6], [7]]] ==> [8]

# %%
def data_to_x_y(data, window_size = 5):
    df = data.to_numpy()
    x = []
    y = []
    for i in range(len(df) - window_size):
        row = [[a] for a in df[i : i + 5]]
        x.append(row)
        label = df[i + 5]
        y.append(label)
    return np.array(x), np.array(y)

# %%
x, y = data_to_x_y(temp, 5)
x.shape, y.shape
x_train, y_train = x[:60000], y[:60000]

# %%
# x

# %%
# y

# %% [markdown]
# # Splitting the data

# %%
x_train, y_train = x[ : 60000], y[ : 60000]
x_val, y_val = x[60000 : 65000], y[60000 : 65000]
x_test, y_test = x[65000 : ], y[65000 : ]
print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
print(x_test.shape, y_test.shape)
# Out:
# (60000, 5, 1) (60000,)
# (5000, 5, 1) (5000,)
# (5086, 5, 1) (5086,)

# %%
from keras.models import Sequential
from keras.layers import *
from keras.callbacks import ModelCheckpoint
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.optimizers import Adam

# %%
model = Sequential()

model.add(InputLayer((5, 1)))
model.add(LSTM(64))
model.add(Dense(8, 'relu'))
model.add(Dense(1, 'linear'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17425 (68.07 KB)
# Trainable params: 17425 (68.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cb = ModelCheckpoint("model", save_best_only = True)
model.compile(loss = MeanSquaredError(), optimizer = Adam(learning_rate=0.0001), metrics = [RootMeanSquaredError()])

# %%
model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs = 10, callbacks = [cb])
# Out:
# Epoch 1/10
# 1871/1875 [============================>.] - ETA: 0s - loss: 35.0608 - root_mean_squared_error: 5.9212INFO:tensorflow:Assets written to: model\assets
# INFO:tensorflow:Assets written to: model\assets
# 1875/1875 [==============================] - 11s 5ms/step - loss: 34.9982 - root_mean_squared_error: 5.9159 - val_loss: 1.5752 - val_root_mean_squared_error: 1.2551
# Epoch 2/10
# 1866/1875 [============================>.] - ETA: 0s - loss: 2.7742 - root_mean_squared_error: 1.6656INFO:tensorflow:Assets written to: model\assets
# INFO:tensorflow:Assets written to: model\assets
# 1875/1875 [==============================] - 9s 5ms/step - loss: 2.7667 - root_mean_squared_error: 1.6633 - val_loss: 0.7096 - val_root_mean_squared_error: 0.8424
# Epoch 3/10
# 1861/1875 [============================>.] - ETA: 0s - loss: 1.0489 - root_mean_squared_error: 1.0242INFO:tensorflow:Assets written to: model\assets
# INFO:tensorflow:Assets written to: model\assets
# 1875/1875 [==============================] - 9s 5ms/step - loss: 1.0476 - root_mean_squared_error: 1.0235 - val_loss: 0.5320 - val_root_mean_squared_error: 0.7294
# Epoch 4/10
# 1862/1875 [============================>.] - ETA: 0s - loss: 0.7521 - root_mean_squared_error: 0.8672INFO:tensorflow:Assets written to: model\assets
# INFO:tensorflow:Assets written to: model\assets
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.7523 - root_mean_squared_error: 0.8674 - val_loss: 0.5099 - val_root_mean_squared_error: 0.7141
# Epoch 5/10
# 1875/1875 [==============================] - ETA: 0s - loss: 0.6930 - root_mean_squared_error: 0.8324INFO:tensorflow:Assets written to: model\assets
# INFO:tensorflow:Assets written to: model\assets
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.6930 - root_mean_squared_error: 0.8324 - val_loss: 0.5079 - val_root_mean_squared_error: 0.7127
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6712 - root_mean_squared_error: 0.8193 - val_loss: 0.5423 - val_root_mean_squared_error: 0.7364
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6605 - root_mean_squared_error: 0.8127 - val_loss: 0.5119 - val_root_mean_squared_error: 0.7154
# Epoch 8/10
# 1875/1875 [==============================] - ETA: 0s - loss: 0.6542 - root_mean_squared_error: 0.8088INFO:tensorflow:Assets written to: model\assets
# INFO:tensorflow:Assets written to: model\assets
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.6542 - root_mean_squared_error: 0.8088 - val_loss: 0.4943 - val_root_mean_squared_error: 0.7031
# Epoch 9/10
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.6501 - root_mean_squared_error: 0.8063INFO:tensorflow:Assets written to: model\assets
# INFO:tensorflow:Assets written to: model\assets
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.6497 - root_mean_squared_error: 0.8061 - val_loss: 0.4897 - val_root_mean_squared_error: 0.6998
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.6459 - root_mean_squared_error: 0.8037 - val_loss: 0.4966 - val_root_mean_squared_error: 0.7047

# %%
from keras.models import load_model
model = load_model("model")

# %%
train_predictions = model.predict(x_train).flatten()
train_results = pd.DataFrame(data = {"Train Predictions" : train_predictions, "Actual" : y_train})
# Out:
# 1875/1875 [==============================] - 5s 2ms/step

# %%
plt.figure(figsize=(30, 10))
sns.scatterplot(data = train_results)
# Out:
# <Axes: >

# %%
test_predictions = model.predict(x_test).flatten()
test_results = pd.DataFrame(data = {"Train Predictions" : test_predictions, "Actual" : y_test})
plt.figure(figsize=(30, 10))
sns.lineplot(data = test_results[:100])
# Out:
# 159/159 [==============================] - 1s 2ms/step
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error as mse
def plotPredictions(model, x, y, start = 0, end = 100):
    pred = model.predict(x).flatten()
    df = pd.DataFrame(data = {"Predictions" : pred, "Actuals" : y})
    sns.lineplot(data = df[start : end])
    return df, mse(y, pred)

# %%
plotPredictions(model, x_test, y_test)
# Out:
# 159/159 [==============================] - 0s 2ms/step
# (      Predictions  Actuals
#  0       14.384392    13.99
#  1       13.241681    13.46
#  2       12.886991    12.93
#  3       12.500876    12.43
#  4       12.051391    12.17
#  ...           ...      ...
#  5081    -0.949444    -0.98
#  5082    -1.390836    -1.40
#  5083    -1.633375    -2.75
#  5084    -3.235053    -2.89
#  5085    -3.158101    -3.93
#
#  [5086 rows x 2 columns],
#  0.6598865180177206)

# %%
model2 = Sequential()

model2.add(InputLayer((5, 1)))
model2.add(Conv1D(64, kernel_size = 5))
model2.add(Flatten())
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'linear'))
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1, 64)             384
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense_2 (Dense)             (None, 8)                 520
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 913 (3.57 KB)
# Trainable params: 913 (3.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cb2 = ModelCheckpoint("model2", save_best_only = True)
model2.compile(loss = MeanSquaredError(), optimizer = Adam(learning_rate=0.0001), metrics = [RootMeanSquaredError()])
model2.fit(x_train, y_train, validation_data=(x_val, y_val), epochs = 10, callbacks = [cb2])
# Out:
# Epoch 1/10
# 1868/1875 [============================>.] - ETA: 0s - loss: 0.6553 - root_mean_squared_error: 0.8095INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6550 - root_mean_squared_error: 0.8093 - val_loss: 0.4982 - val_root_mean_squared_error: 0.7058
# Epoch 2/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6554 - root_mean_squared_error: 0.8096 - val_loss: 0.4991 - val_root_mean_squared_error: 0.7065
# Epoch 3/10
# 1865/1875 [============================>.] - ETA: 0s - loss: 0.6535 - root_mean_squared_error: 0.8084INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.6540 - root_mean_squared_error: 0.8087 - val_loss: 0.4883 - val_root_mean_squared_error: 0.6988
# Epoch 4/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6504 - root_mean_squared_error: 0.8065 - val_loss: 0.4908 - val_root_mean_squared_error: 0.7006
# Epoch 5/10
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.6478 - root_mean_squared_error: 0.8048INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.6479 - root_mean_squared_error: 0.8049 - val_loss: 0.4854 - val_root_mean_squared_error: 0.6967
# Epoch 6/10
# 1851/1875 [============================>.] - ETA: 0s - loss: 0.6489 - root_mean_squared_error: 0.8055INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.6482 - root_mean_squared_error: 0.8051 - val_loss: 0.4852 - val_root_mean_squared_error: 0.6966
# Epoch 7/10
# 1856/1875 [============================>.] - ETA: 0s - loss: 0.6474 - root_mean_squared_error: 0.8046INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.6478 - root_mean_squared_error: 0.8048 - val_loss: 0.4840 - val_root_mean_squared_error: 0.6957
# Epoch 8/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6473 - root_mean_squared_error: 0.8045 - val_loss: 0.5073 - val_root_mean_squared_error: 0.7122
# Epoch 9/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6468 - root_mean_squared_error: 0.8042 - val_loss: 0.4886 - val_root_mean_squared_error: 0.6990
# Epoch 10/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6460 - root_mean_squared_error: 0.8038 - val_loss: 0.5005 - val_root_mean_squared_error: 0.7074

# %%
model3 = Sequential()

model3.add(InputLayer((5, 1)))
model3.add(GRU(64))
model3.add(Flatten())
model3.add(Dense(8, 'relu'))
model3.add(Dense(1, 'linear'))
model3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 64)                12864
#
#  flatten_2 (Flatten)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 8)                 520
#
#  dense_7 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 13393 (52.32 KB)
# Trainable params: 13393 (52.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cb3 = ModelCheckpoint("model3", save_best_only = True)
model3.compile(loss = MeanSquaredError(), optimizer = Adam(learning_rate=0.0001), metrics = [RootMeanSquaredError()])
model3.fit(x_train, y_train, validation_data=(x_val, y_val), epochs = 10, callbacks = [cb3])
# Out:
# Epoch 1/10
# 1872/1875 [============================>.] - ETA: 0s - loss: 28.1975 - root_mean_squared_error: 5.3101INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 10s 4ms/step - loss: 28.1622 - root_mean_squared_error: 5.3068 - val_loss: 1.0267 - val_root_mean_squared_error: 1.0133
# Epoch 2/10
# 1862/1875 [============================>.] - ETA: 0s - loss: 1.6271 - root_mean_squared_error: 1.2756INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.6235 - root_mean_squared_error: 1.2742 - val_loss: 0.5927 - val_root_mean_squared_error: 0.7699
# Epoch 3/10
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.8370 - root_mean_squared_error: 0.9149INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.8372 - root_mean_squared_error: 0.9150 - val_loss: 0.5361 - val_root_mean_squared_error: 0.7322
# Epoch 4/10
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.6997 - root_mean_squared_error: 0.8365INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.6996 - root_mean_squared_error: 0.8364 - val_loss: 0.5058 - val_root_mean_squared_error: 0.7112
# Epoch 5/10
# 1857/1875 [============================>.] - ETA: 0s - loss: 0.6629 - root_mean_squared_error: 0.8142INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.6623 - root_mean_squared_error: 0.8138 - val_loss: 0.5029 - val_root_mean_squared_error: 0.7091
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6498 - root_mean_squared_error: 0.8061 - val_loss: 0.5035 - val_root_mean_squared_error: 0.7096
# Epoch 7/10
# 1866/1875 [============================>.] - ETA: 0s - loss: 0.6446 - root_mean_squared_error: 0.8029INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.6439 - root_mean_squared_error: 0.8024 - val_loss: 0.4938 - val_root_mean_squared_error: 0.7027
# Epoch 8/10
# 1868/1875 [============================>.] - ETA: 0s - loss: 0.6413 - root_mean_squared_error: 0.8008INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.6407 - root_mean_squared_error: 0.8004 - val_loss: 0.4884 - val_root_mean_squared_error: 0.6989
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6387 - root_mean_squared_error: 0.7992 - val_loss: 0.4887 - val_root_mean_squared_error: 0.6990
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6374 - root_mean_squared_error: 0.7984 - val_loss: 0.5122 - val_root_mean_squared_error: 0.7157

# %%
temp
# Out:
# Date Time
# 2009-01-01 01:00:00   -8.05
# 2009-01-01 02:00:00   -8.88
# 2009-01-01 03:00:00   -8.81
# 2009-01-01 04:00:00   -9.05
# 2009-01-01 05:00:00   -9.63
#                        ...
# 2016-12-31 19:10:00   -0.98
# 2016-12-31 20:10:00   -1.40
# 2016-12-31 21:10:00   -2.75
# 2016-12-31 22:10:00   -2.89
# 2016-12-31 23:10:00   -3.93
# Name: T (degC), Length: 70091, dtype: float64

# %%
temp_df = pd.DataFrame({"Temperature" : temp})

# %%
temp_df.head()
# Out:
#                      Temperature
# Date Time
# 2009-01-01 01:00:00        -8.05
# 2009-01-01 02:00:00        -8.88
# 2009-01-01 03:00:00        -8.81
# 2009-01-01 04:00:00        -9.05
# 2009-01-01 05:00:00        -9.63

# %%
temp_df['Seconds'] = temp_df.index.map(pd.Timestamp.timestamp)

# %%
temp_df.head()
# Out:
#                      Temperature       Seconds
# Date Time
# 2009-01-01 01:00:00        -8.05  1.230772e+09
# 2009-01-01 02:00:00        -8.88  1.230775e+09
# 2009-01-01 03:00:00        -8.81  1.230779e+09
# 2009-01-01 04:00:00        -9.05  1.230782e+09
# 2009-01-01 05:00:00        -9.63  1.230786e+09

# %%
day = 60 * 60 * 24
year = 365.2425 * day
